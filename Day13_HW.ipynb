# %% [markdown]
# # [作業目標]
#
#
# 1. 請接下列資料依照指定規則做合併：
#
# ```
# - 依照 fruit 欄位做合併
# - 依照 index 索引做合併
# ```
#
# 2. [簡答題] 承上題，請問為什麼依照 merge 合併後有些資料不見了？
#
# 3. [簡答題] 承上題，請問為什麼依照 index 合併會發生錯誤？請用程式解決。

# %% [markdown]
# # 作業

# %%
# 記得先 Import 正確的套件

'''
Your Code
'''
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. 請接下列資料依照指定規則做合併：
#
# ```
# - 依照 fruit 欄位做合併
# - 依照 index 索引做合併
# ```

# %%
df1 = pd.DataFrame({
    'fruit': ['apple', 'banana', 'orange'] * 3,
    'weight': ['high', 'medium', 'low'] * 3,
    'price': np.random.randint(0, 15, 9)
})

df2 = pd.DataFrame({
    'fruit': ['apple', 'orange', 'pine'] * 2,
    'weight': ['high', 'low'] * 3,
    'price': np.random.randint(0, 15, 6)
})
print(df1)
print(df2)
# Out:
#     fruit  weight  price
# 0   apple    high      7
# 1  banana  medium      5
# 2  orange     low      5
# 3   apple    high      7
# 4  banana  medium     13
# 5  orange     low      6
# 6   apple    high     10
# 7  banana  medium     14
# 8  orange     low      2
#     fruit weight  price
# 0   apple   high      6
# 1  orange    low      3
# 2    pine   high     10
# 3   apple    low     12
# 4  orange   high      0
# 5    pine    low      4

# %%
# - 依照 fruit 欄位做合併

'''
Your Code
'''
pd.merge(df1, df2, how = 'outer', on = 'fruit')
# Out:
#      fruit weight_x  price_x weight_y  price_y
# 0    apple     high      7.0     high      6.0
# 1    apple     high      7.0      low     12.0
# 2    apple     high      7.0     high      6.0
# 3    apple     high      7.0      low     12.0
# 4    apple     high     10.0     high      6.0
# 5    apple     high     10.0      low     12.0
# 6   banana   medium      5.0      NaN      NaN
# 7   banana   medium     13.0      NaN      NaN
# 8   banana   medium     14.0      NaN      NaN
# 9   orange      low      5.0      low      3.0
# 10  orange      low      5.0     high      0.0
# 11  orange      low      6.0      low      3.0
# 12  orange      low      6.0     high      0.0
# 13  orange      low      2.0      low      3.0
# 14  orange      low      2.0     high      0.0
# 15    pine      NaN      NaN     high     10.0
# 16    pine      NaN      NaN      low      4.0

# %%
# - 依照 index 索引做合併

'''
Your Code
'''
pd.merge(df1, df2, on = 'index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-7d4a1b96d468> in <module>
#       4 Your Code
#       5 '''
# ----> 6 pd.merge(df1, df2,how = 'outer', on = 'index')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     624             self.right_join_keys,
#     625             self.join_names,
# --> 626         ) = self._get_merge_keys()
#     627
#     628         # validate the merge keys dtypes. We may need to coerce
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     973                     if not is_rkey(rk):
#     974                         if rk is not None:
# --> 975                             right_keys.append(right._get_label_or_level_values(rk))
#     976                         else:
#     977                             # work-around for merge_asof(right_index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'index'

# %% [markdown]
# ### 2. [簡答題] 承上題，請問為什麼依照 merge 合併後有些資料不見了？

# %%
'''
Your Code
'''
#如果沒有設定合併方法的話會依照預設方法 'inner' 去做合併, 但改用 'outer' 就能解決了

# %% [markdown]
# ### 3. [簡答題] 承上題，請問為什麼依照 index 合併會發生錯誤？請用程式解決。

# %%
'''
Your Code
'''
df1.join(df2, lsuffix = '_df1', rsuffix = '_df2')
# Out:
#   fruit_df1 weight_df1  price_df1 fruit_df2 weight_df2  price_df2
# 0     apple       high          7     apple       high        6.0
# 1    banana     medium          5    orange        low        3.0
# 2    orange        low          5      pine       high       10.0
# 3     apple       high          7     apple        low       12.0
# 4    banana     medium         13    orange       high        0.0
# 5    orange        low          6      pine        low        4.0
# 6     apple       high         10       NaN        NaN        NaN
# 7    banana     medium         14       NaN        NaN        NaN
# 8    orange        low          2       NaN        NaN        NaN

# %%
# Out:
#   fruit_df1 weight_df1  price_df1 fruit_df2 weight_df2  price_df2
# 0     apple       high          3     apple       high        3.0
# 1    banana     medium          6    orange        low        2.0
# 2    orange        low          0      pine       high       11.0
# 3     apple       high          5     apple        low        3.0
# 4    banana     medium          1    orange       high       13.0
# 5    orange        low          2      pine        low        8.0
# 6     apple       high         12       NaN        NaN        NaN
# 7    banana     medium         11       NaN        NaN        NaN
# 8    orange        low          7       NaN        NaN        NaN
